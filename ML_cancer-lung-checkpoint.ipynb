# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Documents\3nd_year\Semester2\Data Analyze\Data\cancer-patient-datasets.csv", index_col=None)
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %% [markdown]
# 1. Thông tin về dataset

# %%
print(f"Shape: {df.shape}")
# Out:
# Shape: (1000, 26)

# %% [markdown]
# => dataset có 1000 bản ghi cùng 26 đặc tính

# %%
list(df.columns)
# Out:
# ['index',
#  'Patient Id',
#  'Age',
#  'Gender',
#  'Air Pollution',
#  'Alcohol use',
#  'Dust Allergy',
#  'OccuPational Hazards',
#  'Genetic Risk',
#  'chronic Lung Disease',
#  'Balanced Diet',
#  'Obesity',
#  'Smoking',
#  'Passive Smoker',
#  'Chest Pain',
#  'Coughing of Blood',
#  'Fatigue',
#  'Weight Loss',
#  'Shortness of Breath',
#  'Wheezing',
#  'Swallowing Difficulty',
#  'Clubbing of Finger Nails',
#  'Frequent Cold',
#  'Dry Cough',
#  'Snoring',
#  'Level']

# %% [markdown]
# => danh sách các đặc tính bao gồm: số tt (index), id bệnh nhân (patient Id), tuổi (age), giới tính (gender), Mức độ tiếp xúc với ô nhiễm không khí của bệnh nhân (air pollution), mức độ sử dụng rượu của bn (alcohol use), mức độ dị ứng bụi của bệnh nhân (dust allergy), Mức độ nguy hiểm nghề nghiệp của bn (occuPational Hazards), Mức độ rủi ro di truyền của bn (genetic risk), Mức độ bệnh phổi mãn tính của bn (chronic lung disease), Mức độ cân bằng chế độ ăn uống của bn (balanced diets), Mức độ béo phì của bn (obesity), Mức độ hút thuốc của bn (smoking), Mức độ hút thuốc thụ động của bn (passive smoker), Mức độ đau ngực của bn (chest pain), Mức độ ho ra máu của bn (coughing of blood), Mức độ mệt mỏi của bn (fatigue), Mức độ sụt cân của bn (weight loss), Mức độ khó thở của bn (shortness of breath), Mức độ thở khò khè của bn (wheezing), Mức độ khó nuốt của bn (swallowing difficulty), Mức độ ngón tay dùi trống của bn (clunning of finger nails), cảm lạnh thường xuyên (frequent cold), ho khan (dry cough), ngáy khi ngủ (snoring), mức độ nghiêm trọng của ung thư phổi (level).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    1000 non-null   int64
#  4   Air Pollution             1000 non-null   int64
#  5   Alcohol use               1000 non-null   int64
#  6   Dust Allergy              1000 non-null   int64
#  7   OccuPational Hazards      1000 non-null   int64
#  8   Genetic Risk              1000 non-null   int64
#  9   chronic Lung Disease      1000 non-null   int64
#  10  Balanced Diet             1000 non-null   int64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   1000 non-null   int64
#  13  Passive Smoker            1000 non-null   int64
# ...

# %% [markdown]
# => dataset có hai biến patient id và level là biến phân loại, còn lại là biến số

# %%
# kiem tra gia tri rong
df.isnull().sum()
# Out:
# index                       0
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %% [markdown]
# => tất cả các biến đều không có giá trị null (giá trị null ở mỗi biến bằng không)

# %%
df.describe()
# Out:
#              index          Age       Gender  Air Pollution  Alcohol use  \
# count  1000.000000  1000.000000  1000.000000      1000.0000  1000.000000
# mean    499.500000    37.174000     1.402000         3.8400     4.563000
# std     288.819436    12.005493     0.490547         2.0304     2.620477
# min       0.000000    14.000000     1.000000         1.0000     1.000000
# 25%     249.750000    27.750000     1.000000         2.0000     2.000000
# 50%     499.500000    36.000000     1.000000         3.0000     5.000000
# 75%     749.250000    45.000000     2.000000         6.0000     7.000000
# max     999.000000    73.000000     2.000000         8.0000     8.000000
#
#        Dust Allergy  OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count   1000.000000           1000.000000   1000.000000           1000.000000
# mean       5.165000              4.840000      4.580000              4.380000
# ...

# %% [markdown]
# => Các biến số đều có phân phối chuẩn, giá tị tb, độ lệch chuẩn, giá trị nhỏ nhất, lớn nhất và các phân vị đều bình thường. Không có dấu hiệu dữ liệu bị thiếu.

# %%
# lấy 5 hàng đầu tiên
df.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
# ...

# %% [markdown]
# 2. Tiền xử lý

# %%
# sắp xếp lại danh sách theo thứ tự id của bệnh nhân và lưu lại vào dataset
df2 = df
df2
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
df2['Id Number'] = df2['Patient Id'].str.extract('(\d+)')
df2.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Weight Loss  \
# 0                     4             3                     2  ...            4
# 1                     3             4                     2  ...            3
# 2                     5             5                     4  ...            7
# 3                     7             6                     7  ...            2
# 4                     7             7                     6  ...            2
#
# ...

# %%
df2['Id Number'] = df2['Id Number'].astype('int')

# %%
df2.dtypes
# Out:
# index                        int64
# Patient Id                  object
# Age                          int64
# Gender                       int64
# Air Pollution                int64
# Alcohol use                  int64
# Dust Allergy                 int64
# OccuPational Hazards         int64
# Genetic Risk                 int64
# chronic Lung Disease         int64
# Balanced Diet                int64
# Obesity                      int64
# Smoking                      int64
# Passive Smoker               int64
# Chest Pain                   int64
# Coughing of Blood            int64
# Fatigue                      int64
# Weight Loss                  int64
# Shortness of Breath          int64
# Wheezing                     int64
# Swallowing Difficulty        int64
# Clubbing of Finger Nails     int64
# Frequent Cold                int64
# Dry Cough                    int64
# Snoring                      int64
# Level                       object
# Id Number                    int32
# ...

# %%
df2 = df2.sort_values(by='Id Number', ascending=True)
df2.head()
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 112    112         P2   25       2              3            1             4
# 223    223         P3   35       1              4            5             6
# 334    334         P4   27       1              2            3             4
# 445    445         P5   48       1              6            7             7
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  \
# 0                       4             3                     2  ...
# 112                     3             2                     3  ...
# 223                     5             6                     5  ...
# 334                     2             4                     3  ...
# 445                     7             7                     6  ...
#
#      Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# ...

# %%
df2 = df2.reset_index(drop=True)
df2.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1    112         P2   25       2              3            1             4
# 2    223         P3   35       1              4            5             6
# 3    334         P4   27       1              2            3             4
# 4    445         P5   48       1              6            7             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Weight Loss  \
# 0                     4             3                     2  ...            4
# 1                     3             2                     3  ...            2
# 2                     5             6                     5  ...            4
# 3                     2             4                     3  ...            2
# 4                     7             7                     6  ...            3
#
# ...

# %%
xóa cột index vì trùng với index

# %% [markdown]
# 3. Thống kê và vẽ biểu đồ

# %% [markdown]
# 4. Mô hình hồi quy tuyến tính 1 biến

# %% [markdown]
# 5. Mô hình hồi quy tuyến tính nhiều biến
